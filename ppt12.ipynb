# %%
class ListNode:
    def __init__(self,val=0,next=None):
        self.val=val
        self.next=next
        
    def deletnode(head):
        if head is not None or head.next is not None:
            return None
        
        slow = head
        fast = head
        prev = None
        
        while fast is not None and fast.next is not None:
            fastclass ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
    def deletenode(head):
        # Check if the head is None or the list has only one node
        if head is None or head.next is None:
            return None
        
        slow = head
        fast = head
        prev = None
        
        # Find the middle node using slow and fast pointers
        while fast is not None and fast.next is not None:
            fast = fast.next.next
            prev = slow
            slow = slow.next
        
        # Delete the middle node by updating the next pointer of the previous node
        prev.next = slow.next
         
        return head
= fast.next.next
            prev=slow
            slow=slow,next
        prev.next=slow.next
         
        return head

# %%
class ListNode:
    
    def checkloop(self, head):
        # Initialize two pointers, slow and fast, pointing to the head of the linked list
        slow = head
        fast = head

        # Traverse the linked list until either the fast pointer reaches the end or they meet (loop is detected)
        while fast is not None and fast.next is not None:
            # Move slow pointer by one step
            slow = slow.next
            # Move fast pointer by two steps
            fast = fast.next.next

            # If the slow and fast pointers meet, there is a loop in the linked list
            if slow == fast:
                return True

        # No loop found in the linked list
        return False

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def findNthFromEnd(head, n):
    if head is None:
        return None

    slow = head
    fast = head

    # Move the fast pointer ahead by n nodes
    for _ in range(n):
        if fast is None:
            return None
        fast = fast.next

    # Move both pointers until the fast pointer reaches the end
    while fast is not None and fast.next is not None:
        slow = slow.next
        fast = fast.next

    # At this point, the slow pointer is at the Nth node from the end
    return slow.val

# %%
class linklist:
    def __init(self,val=0,next=None):
        self.val=val
        self.next=next
        
    def palindrome(head):
        slow=head
        fast=head
        while(fast is not None and fast.next is not None):
            slow=slow.next
            fast=fast.next.next
        #reverse the 2nd half    
        prev =slow
        slow=slow.next
        prev.next=null
        while(slow.next is not None):
            temp.next=slow
            slow.next=prev
            prev=slow
            slow=temp
            
        #travesse and check
        fast=head#fast at start
        slow=prev#slow at last
        
        while(slow is not None):
            if(slow.val != fast.next):
                return Fasle
        
        return True

# %%
class linklist:
    def __init(self,val=0,next=None):
        self.val=val
        self.next=next
        
    def detecttheloop(head):
        if head.next is None:
            return None
        
        slow=hesd
        fast=head
        #check the loop
        has_loop=False
        while(fast is not None and fast.next is not None):
            slow=slow.next
            fast=fast.next.next
            if (slow==fast):
                has_loop=True
                break
            # delete the loop
            if has_loop:
                slow=head#taking the slow out of the loop 
                while (slow.next != fast.next):
                    slow=slow.next
                    fast=fast.next
                fast.next=none

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def retainAndDelete(head, M, N):
    if head is None or M <= 0 or N <= 0:
        return head

    current = head
    previous = None

    while current is not None:
        # Retain M nodes
        for _ in range(M):
            if current is None:
                return head
            previous = current
            current = current.next

        # Delete N nodes
        for _ in range(N):
            if current is None:
                break
            current = current.next

        # Connect the previous node to the next retained node
        previous.next = current

    return head

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def mergeLists(first, second):
    if first is None:
        return second

    current_first = first
    current_second = second

    while current_first is not None and current_second is not None:
        # Store the next nodes of the original lists
        next_first = current_first.next
        next_second = current_second.next

        # Insert the second list node after the first list node
        current_first.next = current_second
        current_second.next = next_first

        # Update the current nodes to their respective next nodes
        current_first = next_first
        current_second = next_second

    return first

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def isCircular(head):
    if head is None:
        return False

    slow = head
    fast = head.next

    # Traverse the linked list using the slow and fast pointers
    while fast is not None and fast.next is not None:
        if slow == fast:
            # If slow and fast pointers meet, the linked list is circular
            return True
        slow = slow.next
        fast = fast.next.next

    # No meeting point found, the linked list is not circular
    return False
