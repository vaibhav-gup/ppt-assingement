# %%
1
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

def merge_linked_lists(head1, head2):
    newHead = None
    current = None

    while head1 and head2:
        if head1.value >= head2.value:
            newNode = Node(head1.value)
            head1 = head1.next
        else:
            newNode = Node(head2.value)
            head2 = head2.next

        if newHead is None:
            newHead = newNode
            current = newHead
        else:
            current.next = newNode
            current = current.next

    # Append remaining nodes from either linked list
    while head1:
        newNode = Node(head1.value)
        current.next = newNode
        current = current.next
        head1 = head1.next

    while head2:
        newNode = Node(head2.value)
        current.next = newNode
        current = current.next
        head2 = head2.next

    return newHead

# %%
2
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        
    def duplicate(head):
        if head==None:
            return head
        
        current=head
        while current.next is not None:
            if current.value==current.next.value:
                current.value=current.next.next
            else:
                current=current.next
                
        return head

# %%
3
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

def reverse_k_nodes(head, k):
    if not head or k == 1:
        return head

    dummy = Node(0)
    dummy.next = head
    prev = dummy

    while True:
        count = 0
        current = prev.next
        while current:
            count += 1
            current = current.next
            if count == k:
                break

        if count != k:
            break

        current = prev.next
        for _ in range(k - 1):
            next_node = current.next
            current.next = next_node.next
            next_node.next = prev.next
            prev.next = next_node

        prev = current

    return dummy.next

# %%
4
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

def reverse_alternate_k_nodes(head, k):
    if not head or k == 1:
        return head

    dummy = Node(0)
    dummy.next = head
    prev = dummy
    current = head
    is_reversed = True

    while current:
        count = 0
        while current and count < k:
            current = current.next
            count += 1

        if is_reversed:
            prev.next = reverse_list(prev.next, count)
        else:
            for _ in range(count):
                prev = prev.next

        is_reversed = not is_reversed

    return dummy.next

def reverse_list(head, count):
    prev = None
    current = head

    while count > 0:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
        count -= 1

    head.next = current

    return prev

# %%
5
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

def delete_last_occurrence(head, key):
    if not head:
        return None

    last_occurrence = None
    prev = None
    current = head

    while current:
        if current.value == key:
            last_occurrence = current
        prev = current
        current = current.next

    if last_occurrence is None:
        return head

    if prev is None:
        head = head.next
    else:
        prev.next = last_occurrence.next

    return head

# %%
6
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

def merge_sorted_lists(list1, list2):
    if not list1:
        return list2
    if not list2:
        return list1

    result = None
    current = None

    while list1 and list2:
        if list1.value <= list2.value:
            if result is None:
                result = list1
                current = result
            else:
                current.next = list1
                current = current.next
            list1 = list1.next
        else:
            if result is None:
                result = list2
                current = result
            else:
                current.next = list2
                current = current.next
            list2 = list2.next

    if list1:
        current.next = list1
    if list2:
        current.next = list2

    return result

# %%
7
class Node:
    def __init__(self, value):
        self.value = value
        self.prev = None
        self.next = None

def reverse_doubly_linked_list(head):
    if not head:
        return None

    current = head

    while current:
        temp = current.prev
        current.prev = current.next
        current.next = temp
        current = current.prev

    if temp:
        head = temp.prev

    return head

# %%
8
class Node:
    def __init__(self, value):
        self.value = value
        self.prev = None
        self.next = None

def delete_node_from_position(head, position):
    if not head:
        return None

    current = head
    count = 1

    while current and count < position:
        current = current.next
        count += 1

    if not current:
        return head

    if current == head:
        head = current.next

    if current.next:
        current.next.prev = current.prev

    if current.prev:
        current.prev.next = current.next

    current.prev = None
    current.next = None

    return head
